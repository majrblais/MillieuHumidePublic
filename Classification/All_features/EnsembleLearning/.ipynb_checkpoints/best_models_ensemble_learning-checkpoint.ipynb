# %%
import pandas as pd
import matplotlib.pyplot as plt
import ast
import numpy as np
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import warnings

warnings.filterwarnings("ignore")

# List of feature selection techniques
feature_selection_techniques = [
    "SelectKBest_f_classif",
    "SelectKBest_mutual_info_classif",
    "VarianceThreshold"
]

result_columns_list = ['PR', 'NR', 'SR', 'WS', 'SFST', 'PR_Benefit', 'NR_Benefit', 'SR_Benefit', 'WS_Benefit', 'SFST_Benefit']

for result_column in result_columns_list:
    # Load the test results from the CSV file
    test_results_df = pd.read_csv(f"test_results_{result_column}.csv")
    TITLE = result_column

    # Dictionary to store the best results for each feature selection technique
    best_results = []

    # Set to store all unique features
    all_features = set()

    # Iterate over each feature selection technique
    for technique in feature_selection_techniques:
        # Filter results for the current technique
        technique_results = test_results_df[test_results_df['Selection Method'] == technique]
        
        # Select the top three results based on highest accuracy
        top_three_rows = technique_results.nlargest(3, 'Accuracy')
        
        # Iterate over the top three rows
        for idx, best_row in top_three_rows.iterrows():
            # Extract actual and predicted values
            actual_values = list(map(int, best_row['Actual'].split(',')))
            predicted_values = list(map(int, best_row['Predicted'].split(',')))
            features = ast.literal_eval(best_row['Selected Features'])

            # Add the features to the set of all features
            all_features.update(features)
            
            # Store the best result
            best_results.append({
                'Selection Method': technique,
                'Accuracy': best_row['Accuracy'],
                'Actual': actual_values,
                'Predicted': predicted_values,
                'Number of Features': len(features),
                'Selected Features': features
            })

    # Sort the best results based on accuracy and select the top 3 for ensemble and top 2 for plotting
    best_results = sorted(best_results, key=lambda x: -x['Accuracy'])
    top_2_results = best_results[:2]
    top_5_results = best_results[:5]

    # Print a summary table of the top 2 models
    summary_table = pd.DataFrame(top_2_results)
    print(f"Summary of the top 2 models for {result_column}:")
    print(summary_table[['Selection Method', 'Accuracy', 'Number of Features', 'Selected Features']])

    # Generate and plot confusion matrices for the top 2 models
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    axes = axes.flatten()

    for idx, results in enumerate(top_2_results):
        cm = confusion_matrix(results['Actual'], results['Predicted'])
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=axes[idx])
        axes[idx].set_title(f"{results['Selection Method']} (Accuracy: {results['Accuracy']:.4f})")
        axes[idx].set_xlabel('Predicted')
        axes[idx].set_ylabel('Actual')

    # Calculate ensemble predictions
    ensemble_actual = top_5_results[0]['Actual']
    ensemble_predicted = np.round(np.mean(
        [results['Predicted'] for results in top_5_results],
        axis=0
    )).astype(int)

    # Calculate ensemble accuracy
    ensemble_accuracy = accuracy_score(ensemble_actual, ensemble_predicted)

    # Add the ensemble approach to the plot
    cm_ensemble = confusion_matrix(ensemble_actual, ensemble_predicted)
    sns.heatmap(cm_ensemble, annot=True, fmt="d", cmap="Blues", ax=axes[2])
    axes[2].set_title(f"Ensemble (Top 5 models) (Accuracy: {ensemble_accuracy:.4f})")
    axes[2].set_xlabel('Predicted')
    axes[2].set_ylabel('Actual')

    plt.tight_layout()
    plt.savefig(f"confusion_matrices_{TITLE}.png")
    plt.show()

    # Find the method with the highest accuracy and lowest number of features
    best_method = min(best_results, key=lambda x: (-x['Accuracy'], x['Number of Features']))
    print(f"\nMethod with the highest accuracy and lowest number of features for {result_column}:")
    print(best_method)

    # Find the method with the highest accuracy proportionate to the number of features
    best_method_proportionate = max(best_results, key=lambda x: (x['Accuracy'] / x['Number of Features']))
    print(f"\nMethod with the highest accuracy proportionate to the number of features for {result_column}:")
    print(best_method_proportionate)
# Out:
# Summary of the top 2 models for PR:
#         Selection Method  Accuracy  Number of Features  \
# 0  SelectKBest_f_classif  0.952381                   8
# 1  SelectKBest_f_classif  0.952381                   9
#
#                               Selected Features
# 0       [F1, F14, F24, F28, F41, F43, F44, F45]
# 1  [F1, F14, F24, F28, F41, F43, F44, F45, F46]
# Method with the highest accuracy and lowest number of features for PR:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 0.9523809523809524, 'Actual': [2, 2, 2, 1, 2, 1, 1, 2, 1, 1, 1, 2, 1, 2, 0, 1, 2, 1, 1, 2, 1], 'Predicted': [2, 2, 2, 1, 2, 1, 1, 2, 1, 1, 1, 2, 1, 2, 1, 1, 2, 1, 1, 2, 1], 'Number of Features': 8, 'Selected Features': ['F1', 'F14', 'F24', 'F28', 'F41', 'F43', 'F44', 'F45']}
#
# Method with the highest accuracy proportionate to the number of features for PR:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 0.9523809523809524, 'Actual': [2, 2, 2, 1, 2, 1, 1, 2, 1, 1, 1, 2, 1, 2, 0, 1, 2, 1, 1, 2, 1], 'Predicted': [2, 2, 2, 1, 2, 1, 1, 2, 1, 1, 1, 2, 1, 2, 1, 1, 2, 1, 1, 2, 1], 'Number of Features': 8, 'Selected Features': ['F1', 'F14', 'F24', 'F28', 'F41', 'F43', 'F44', 'F45']}
# Summary of the top 2 models for NR:
#         Selection Method  Accuracy  Number of Features  \
# 0  SelectKBest_f_classif  0.809524                  13
# 1  SelectKBest_f_classif  0.809524                  14
#
#                                    Selected Features
# 0  [F1, F14, F22, F23, F24, F28, F29, F30, F43, F...
# 1  [F1, F3_e, F14, F22, F23, F24, F28, F29, F30, ...
# Method with the highest accuracy and lowest number of features for NR:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 0.8095238095238095, 'Actual': [2, 2, 2, 1, 0, 1, 1, 2, 1, 0, 0, 2, 1, 2, 0, 0, 2, 0, 1, 1, 1], 'Predicted': [2, 2, 2, 1, 0, 1, 0, 2, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 1, 0, 1], 'Number of Features': 13, 'Selected Features': ['F1', 'F14', 'F22', 'F23', 'F24', 'F28', 'F29', 'F30', 'F43', 'F44', 'F45', 'F46', 'F47']}
#
# Method with the highest accuracy proportionate to the number of features for NR:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 0.8095238095238095, 'Actual': [2, 2, 2, 1, 0, 1, 1, 2, 1, 0, 0, 2, 1, 2, 0, 0, 2, 0, 1, 1, 1], 'Predicted': [2, 2, 2, 1, 0, 1, 0, 2, 1, 1, 0, 2, 1, 2, 0, 0, 2, 1, 1, 0, 1], 'Number of Features': 13, 'Selected Features': ['F1', 'F14', 'F22', 'F23', 'F24', 'F28', 'F29', 'F30', 'F43', 'F44', 'F45', 'F46', 'F47']}
# Summary of the top 2 models for SR:
#         Selection Method  Accuracy  Number of Features  \
# 0  SelectKBest_f_classif  0.952381                  14
# 1  SelectKBest_f_classif  0.952381                  15
#
#                                    Selected Features
# 0  [OF22, F1, F3_e, F13, F14, F25, F35, F36, F41,...
# 1  [OF22, F1, F3_e, F13, F14, F23, F25, F35, F36,...
# Method with the highest accuracy and lowest number of features for SR:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 0.9523809523809524, 'Actual': [2, 2, 2, 1, 0, 0, 0, 1, 1, 0, 0, 2, 1, 1, 0, 0, 1, 0, 1, 0, 1], 'Predicted': [2, 2, 2, 1, 0, 0, 0, 2, 1, 0, 0, 2, 1, 1, 0, 0, 1, 0, 1, 0, 1], 'Number of Features': 14, 'Selected Features': ['OF22', 'F1', 'F3_e', 'F13', 'F14', 'F25', 'F35', 'F36', 'F41', 'F43', 'F44', 'F45', 'F46', 'F49']}
#
# Method with the highest accuracy proportionate to the number of features for SR:
# {'Selection Method': 'SelectKBest_mutual_info_classif', 'Accuracy': 0.9047619047619048, 'Actual': [2, 2, 2, 1, 0, 0, 0, 1, 1, 0, 0, 2, 1, 1, 0, 0, 1, 0, 1, 0, 1], 'Predicted': [2, 2, 2, 1, 0, 0, 0, 2, 0, 0, 0, 2, 1, 1, 0, 0, 1, 0, 1, 0, 1], 'Number of Features': 9, 'Selected Features': ['OF22', 'F24', 'F28', 'F30', 'F31', 'F43', 'F44', 'F45', 'F46']}
# Summary of the top 2 models for WS:
#         Selection Method  Accuracy  Number of Features  \
# 0  SelectKBest_f_classif       1.0                  41
# 1  SelectKBest_f_classif       1.0                  43
#
#                                    Selected Features
# 0  [OF22, OF24, OF25, OF26, OF28, F1, F3_c, F3_d,...
# 1  [OF22, OF24, OF25, OF26, OF28, F1, F3_c, F3_d,...
# Method with the highest accuracy and lowest number of features for WS:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 1.0, 'Actual': [2, 1, 1, 1, 0, 0, 0, 2, 1, 0, 1, 2, 1, 2, 0, 0, 2, 0, 0, 1, 0], 'Predicted': [2, 1, 1, 1, 0, 0, 0, 2, 1, 0, 1, 2, 1, 2, 0, 0, 2, 0, 0, 1, 0], 'Number of Features': 41, 'Selected Features': ['OF22', 'OF24', 'OF25', 'OF26', 'OF28', 'F1', 'F3_c', 'F3_d', 'F3_e', 'F4', 'F5', 'F7', 'F9', 'F13', 'F14', 'F17', 'F22', 'F23', 'F24', 'F25', 'F28', 'F29', 'F30', 'F31', 'F32', 'F33', 'F34', 'F35', 'F36', 'F37', 'F40', 'F41', 'F43', 'F44', 'F45', 'F46', 'F47', 'F49', 'F56', 'F65', 'S1']}
#
# Method with the highest accuracy proportionate to the number of features for WS:
# {'Selection Method': 'SelectKBest_mutual_info_classif', 'Accuracy': 0.9523809523809524, 'Actual': [2, 1, 1, 1, 0, 0, 0, 2, 1, 0, 1, 2, 1, 2, 0, 0, 2, 0, 0, 1, 0], 'Predicted': [2, 1, 1, 0, 0, 0, 0, 2, 1, 0, 1, 2, 1, 2, 0, 0, 2, 0, 0, 1, 0], 'Number of Features': 14, 'Selected Features': ['F1', 'F3_e', 'F5', 'F14', 'F24', 'F29', 'F30', 'F31', 'F41', 'F43', 'F44', 'F45', 'F46', 'F65']}
# Summary of the top 2 models for SFST:
#                   Selection Method  Accuracy  Number of Features  \
# 0            SelectKBest_f_classif       1.0                  67
# 1  SelectKBest_mutual_info_classif       1.0                  56
#
#                                    Selected Features
# 0  [OF2, OF10, OF11, OF13, OF17, OF22, OF23, OF24...
# 1  [OF3, OF5, OF6, OF10, OF18, OF23, OF24, OF25, ...
# Method with the highest accuracy and lowest number of features for SFST:
# {'Selection Method': 'SelectKBest_mutual_info_classif', 'Accuracy': 1.0, 'Actual': [0, 0, 0, 2, 2, 2, 2, 0, 1, 2, 1, 0, 1, 0, 2, 1, 0, 2, 2, 1, 2], 'Predicted': [0, 0, 0, 2, 2, 2, 2, 0, 1, 2, 1, 0, 1, 0, 2, 1, 0, 2, 2, 1, 2], 'Number of Features': 56, 'Selected Features': ['OF3', 'OF5', 'OF6', 'OF10', 'OF18', 'OF23', 'OF24', 'OF25', 'OF26', 'OF27', 'OF28', 'OF31', 'OF33', 'F1', 'F3_b', 'F3_c', 'F3_d', 'F3_e', 'F3_f', 'F4', 'F5', 'F9', 'F13', 'F14', 'F15', 'F17', 'F22', 'F23', 'F24', 'F25', 'F28', 'F29', 'F30', 'F31', 'F32', 'F33', 'F34', 'F35', 'F36', 'F37', 'F38', 'F39', 'F40', 'F41', 'F43', 'F44', 'F45', 'F46', 'F47', 'F49', 'F56', 'F58', 'F64', 'F65', 'F67', 'S2']}
#
# Method with the highest accuracy proportionate to the number of features for SFST:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 0.9523809523809524, 'Actual': [0, 0, 0, 2, 2, 2, 2, 0, 1, 2, 1, 0, 1, 0, 2, 1, 0, 2, 2, 1, 2], 'Predicted': [0, 0, 0, 2, 2, 2, 2, 0, 1, 2, 1, 0, 1, 0, 2, 2, 0, 2, 2, 1, 2], 'Number of Features': 2, 'Selected Features': ['F43', 'F44']}
# Summary of the top 2 models for PR_Benefit:
#                   Selection Method  Accuracy  Number of Features  \
# 0  SelectKBest_mutual_info_classif       1.0                  88
# 1  SelectKBest_mutual_info_classif       1.0                  92
#
#                                    Selected Features
# 0  [OF2, OF4, OF5, OF8, OF11, OF13, OF14, OF15, O...
# 1  [OF2, OF4, OF5, OF7, OF8, OF11, OF14, OF15, OF...
# Method with the highest accuracy and lowest number of features for PR_Benefit:
# {'Selection Method': 'SelectKBest_mutual_info_classif', 'Accuracy': 1.0, 'Actual': [0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 1, 0, 2, 0, 2, 1, 0, 2, 2, 0, 0], 'Predicted': [0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 1, 0, 2, 0, 2, 1, 0, 2, 2, 0, 0], 'Number of Features': 88, 'Selected Features': ['OF2', 'OF4', 'OF5', 'OF8', 'OF11', 'OF13', 'OF14', 'OF15', 'OF16', 'OF17', 'OF18', 'OF19', 'OF20', 'OF21', 'OF22', 'OF24', 'OF25', 'OF26', 'OF27', 'OF28', 'OF31', 'OF34', 'OF38', 'F1', 'F2', 'F3_a', 'F3_c', 'F3_e', 'F3_f', 'F3_g', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'F13', 'F14', 'F15', 'F16', 'F17', 'F19', 'F20', 'F21', 'F22', 'F23', 'F24', 'F25', 'F28', 'F29', 'F30', 'F31', 'F32', 'F33', 'F34', 'F35', 'F36', 'F37', 'F38', 'F39', 'F40', 'F41', 'F43', 'F44', 'F45', 'F46', 'F47', 'F48', 'F49', 'F50', 'F51', 'F52', 'F53', 'F54', 'F55', 'F56', 'F57', 'F58', 'F59', 'F62', 'F63', 'F64', 'F65', 'F67', 'F68', 'S1', 'S2', 'S4']}
#
# Method with the highest accuracy proportionate to the number of features for PR_Benefit:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 0.9523809523809524, 'Actual': [0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 1, 0, 2, 0, 2, 1, 0, 2, 2, 0, 0], 'Predicted': [0, 0, 0, 2, 0, 2, 0, 0, 2, 0, 0, 0, 2, 0, 2, 1, 0, 2, 2, 0, 0], 'Number of Features': 38, 'Selected Features': ['OF19', 'OF22', 'OF24', 'F1', 'F3_c', 'F3_d', 'F3_e', 'F3_g', 'F5', 'F9', 'F13', 'F14', 'F17', 'F22', 'F23', 'F24', 'F28', 'F29', 'F30', 'F32', 'F33', 'F34', 'F35', 'F36', 'F37', 'F40', 'F41', 'F43', 'F44', 'F45', 'F46', 'F47', 'F48', 'F50', 'F52', 'F64', 'F65', 'S1']}
# Summary of the top 2 models for NR_Benefit:
#         Selection Method  Accuracy  Number of Features  \
# 0  SelectKBest_f_classif  0.952381                  28
# 1  SelectKBest_f_classif  0.952381                  33
#
#                                    Selected Features
# 0  [OF9, OF10, OF19, OF20, OF21, OF22, OF38, F1, ...
# 1  [OF9, OF10, OF19, OF20, OF21, OF22, OF33, OF38...
# Method with the highest accuracy and lowest number of features for NR_Benefit:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 0.9523809523809524, 'Actual': [0, 0, 0, 2, 0, 1, 1, 0, 2, 0, 1, 0, 2, 0, 1, 1, 0, 2, 1, 0, 1], 'Predicted': [0, 0, 0, 2, 0, 1, 1, 0, 2, 0, 0, 0, 2, 0, 1, 1, 0, 2, 1, 0, 1], 'Number of Features': 28, 'Selected Features': ['OF9', 'OF10', 'OF19', 'OF20', 'OF21', 'OF22', 'OF38', 'F1', 'F3_c', 'F3_d', 'F3_e', 'F9', 'F13', 'F14', 'F22', 'F23', 'F24', 'F30', 'F31', 'F41', 'F43', 'F44', 'F45', 'F46', 'F47', 'F52', 'F65', 'S1']}
#
# Method with the highest accuracy proportionate to the number of features for NR_Benefit:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 0.9523809523809524, 'Actual': [0, 0, 0, 2, 0, 1, 1, 0, 2, 0, 1, 0, 2, 0, 1, 1, 0, 2, 1, 0, 1], 'Predicted': [0, 0, 0, 2, 0, 1, 1, 0, 2, 0, 0, 0, 2, 0, 1, 1, 0, 2, 1, 0, 1], 'Number of Features': 28, 'Selected Features': ['OF9', 'OF10', 'OF19', 'OF20', 'OF21', 'OF22', 'OF38', 'F1', 'F3_c', 'F3_d', 'F3_e', 'F9', 'F13', 'F14', 'F22', 'F23', 'F24', 'F30', 'F31', 'F41', 'F43', 'F44', 'F45', 'F46', 'F47', 'F52', 'F65', 'S1']}
# Summary of the top 2 models for SR_Benefit:
#         Selection Method  Accuracy  Number of Features  \
# 0  SelectKBest_f_classif       1.0                   4
# 1  SelectKBest_f_classif       1.0                   5
#
#              Selected Features
# 0       [OF19, OF21, F41, F43]
# 1  [OF19, OF21, F28, F41, F43]
# Method with the highest accuracy and lowest number of features for SR_Benefit:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 1.0, 'Actual': [0, 0, 0, 2, 0, 1, 0, 0, 2, 0, 0, 0, 2, 0, 1, 0, 0, 1, 1, 0, 0], 'Predicted': [0, 0, 0, 2, 0, 1, 0, 0, 2, 0, 0, 0, 2, 0, 1, 0, 0, 1, 1, 0, 0], 'Number of Features': 4, 'Selected Features': ['OF19', 'OF21', 'F41', 'F43']}
#
# Method with the highest accuracy proportionate to the number of features for SR_Benefit:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 1.0, 'Actual': [0, 0, 0, 2, 0, 1, 0, 0, 2, 0, 0, 0, 2, 0, 1, 0, 0, 1, 1, 0, 0], 'Predicted': [0, 0, 0, 2, 0, 1, 0, 0, 2, 0, 0, 0, 2, 0, 1, 0, 0, 1, 1, 0, 0], 'Number of Features': 4, 'Selected Features': ['OF19', 'OF21', 'F41', 'F43']}
# Summary of the top 2 models for WS_Benefit:
#         Selection Method  Accuracy  Number of Features  \
# 0  SelectKBest_f_classif       1.0                  84
# 1  SelectKBest_f_classif       1.0                  85
#
#                                    Selected Features
# 0  [OF3, OF4, OF5, OF6, OF7, OF8, OF9, OF10, OF14...
# 1  [OF3, OF4, OF5, OF6, OF7, OF8, OF9, OF10, OF14...
# Method with the highest accuracy and lowest number of features for WS_Benefit:
# {'Selection Method': 'SelectKBest_mutual_info_classif', 'Accuracy': 1.0, 'Actual': [1, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 0, 0, 0, 1, 2, 0, 1, 1, 0, 1], 'Predicted': [1, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 0, 0, 0, 1, 2, 0, 1, 1, 0, 1], 'Number of Features': 20, 'Selected Features': ['OF7', 'OF9', 'OF15', 'OF17', 'OF20', 'OF23', 'OF27', 'OF33', 'F3_b', 'F3_c', 'F3_e', 'F4', 'F5', 'F20', 'F31', 'F32', 'F49', 'F50', 'F51', 'S5']}
#
# Method with the highest accuracy proportionate to the number of features for WS_Benefit:
# {'Selection Method': 'SelectKBest_mutual_info_classif', 'Accuracy': 1.0, 'Actual': [1, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 0, 0, 0, 1, 2, 0, 1, 1, 0, 1], 'Predicted': [1, 0, 0, 0, 0, 2, 0, 0, 0, 0, 2, 0, 0, 0, 1, 2, 0, 1, 1, 0, 1], 'Number of Features': 20, 'Selected Features': ['OF7', 'OF9', 'OF15', 'OF17', 'OF20', 'OF23', 'OF27', 'OF33', 'F3_b', 'F3_c', 'F3_e', 'F4', 'F5', 'F20', 'F31', 'F32', 'F49', 'F50', 'F51', 'S5']}
# Summary of the top 2 models for SFST_Benefit:
#         Selection Method  Accuracy  Number of Features  \
# 0  SelectKBest_f_classif  0.952381                  47
# 1  SelectKBest_f_classif  0.952381                  87
#
#                                    Selected Features
# 0  [OF9, OF10, OF17, OF22, OF24, OF25, OF26, OF28...
# 1  [OF2, OF4, OF5, OF6, OF7, OF8, OF9, OF10, OF11...
# Method with the highest accuracy and lowest number of features for SFST_Benefit:
# {'Selection Method': 'SelectKBest_f_classif', 'Accuracy': 0.9523809523809524, 'Actual': [0, 0, 0, 1, 2, 2, 2, 0, 1, 1, 1, 0, 1, 0, 2, 2, 0, 2, 1, 2, 2], 'Predicted': [0, 0, 0, 2, 2, 2, 2, 0, 1, 1, 1, 0, 1, 0, 2, 2, 0, 2, 1, 2, 2], 'Number of Features': 47, 'Selected Features': ['OF9', 'OF10', 'OF17', 'OF22', 'OF24', 'OF25', 'OF26', 'OF28', 'F1', 'F3_c', 'F3_d', 'F3_e', 'F3_f', 'F4', 'F5', 'F7', 'F9', 'F10', 'F13', 'F14', 'F17', 'F19', 'F22', 'F23', 'F24', 'F25', 'F28', 'F29', 'F30', 'F32', 'F33', 'F34', 'F35', 'F36', 'F37', 'F40', 'F41', 'F43', 'F44', 'F45', 'F46', 'F47', 'F49', 'F50', 'F56', 'F65', 'S1']}
#
# Method with the highest accuracy proportionate to the number of features for SFST_Benefit:
# {'Selection Method': 'SelectKBest_mutual_info_classif', 'Accuracy': 0.9047619047619048, 'Actual': [0, 0, 0, 1, 2, 2, 2, 0, 1, 1, 1, 0, 1, 0, 2, 2, 0, 2, 1, 2, 2], 'Predicted': [0, 0, 0, 2, 2, 2, 2, 0, 1, 1, 1, 0, 1, 0, 2, 2, 0, 2, 2, 2, 2], 'Number of Features': 23, 'Selected Features': ['OF22', 'OF28', 'F1', 'F3_c', 'F3_d', 'F3_e', 'F5', 'F9', 'F14', 'F23', 'F24', 'F25', 'F28', 'F29', 'F30', 'F31', 'F33', 'F35', 'F41', 'F43', 'F44', 'F45', 'F46']}
