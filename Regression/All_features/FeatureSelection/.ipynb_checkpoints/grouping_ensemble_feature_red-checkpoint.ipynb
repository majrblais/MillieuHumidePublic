# %%
import pandas as pd
import numpy as np
from collections import Counter
import ast
from sklearn.metrics import mean_squared_error

# Configuration for all functions
config = {
    "WS": {"min": 1.58, "max": 8.61, "lower": 3.07, "higher": 6.17},
    "PR": {"min": 2.07, "max": 10.0, "lower": 3.66, "higher": 6.11},
    "NR": {"min": 4.10, "max": 10.0, "lower": 2.06, "higher": 4.42},
    "SR": {"min": 2.29, "max": 10.0, "lower": 3.02, "higher": 6.67},
    "SFST": {"min": 0.0, "max": 7.71, "lower": 1.05, "higher": 6.51},
    "WS_Benefit": {"min": 0.08, "max": 10.0, "lower": 2.65, "higher": 6.50},
    "PR_Benefit": {"min": 0.49, "max": 10.0, "lower": 3.29, "higher": 6.68},
    "NR_Benefit": {"min": 0.71, "max": 10.0, "lower": 4.10, "higher": 7.76},
    "SR_Benefit": {"min": 0.49, "max": 8.79, "lower": 2.94, "higher": 6.19},
    "SFST_Benefit": {"min": 0.0, "max": 7.19, "lower": 1.86, "higher": 5.30}
}

# Normalize function
def normalize(values, min_val, max_val):
    return 10 * ((values - min_val) / (max_val - min_val))

# Classify function
def classify(value, lower, higher):
    if value < lower:
        return "lower"
    elif value <= higher:
        return "moderate"
    else:
        return "higher"

# Calculate accuracy function
def calculate_accuracy(actual, predicted):
    actual_classes = actual.split(',')
    predicted_classes = predicted.split(',')
    return sum(1 for a, p in zip(actual_classes, predicted_classes) if a == p) / len(actual_classes)
    
# Voting system for ensemble learning
def voting_classification(predictions):
    return [Counter(pred).most_common(1)[0][0] for pred in zip(*predictions)]
    
# Process each function defined in config
for function, params in config.items():
    for norm_type in ['non_norm', 'norm','non_norm_post']:
        test_csv_file = f"test_results_{function}_{norm_type}.csv"
        data = pd.read_csv(test_csv_file)

        # Filter out results with more than 5 features
        data = data[data['Number of Features'] <= 5]

        # Normalize and classify using the parameters specific to each function
        if norm_type == 'non_norm_post':
            data['Normalized_Actual'] = data['Actual']
            data['Normalized_Predicted'] = data['Predicted']
        if norm_type == 'non_norm':
            data['Normalized_Actual'] = data['Actual']
            data['Normalized_Predicted'] = data['Predicted']
        if norm_type == 'norm':
            data['Normalized_Actual'] = data['Actual']
            data['Normalized_Predicted'] = data['Predicted']
            
        data['Classified_Actual'] = data['Normalized_Actual'].apply(lambda x: ','.join([classify(float(val), params['lower'], params['higher']) for val in x.split(',')]))
        data['Classified_Predicted'] = data['Normalized_Predicted'].apply(lambda x: ','.join([classify(float(val), params['lower'], params['higher']) for val in x.split(',')]))

        # Identify the top model based on lowest MSE
        top_model = data.nsmallest(1, 'MSE').iloc[0]

        # Extract features of the top model
        try:
            top_features = ast.literal_eval(top_model['Selected Features'])
        except (ValueError, SyntaxError):
            top_features = top_model['Selected Features'].split(', ')

        # Ensemble accuracy calculation
        top_5_models = data.nsmallest(5, 'MSE')
        ensemble_predictions = top_5_models['Classified_Predicted'].apply(lambda x: x.split(','))
        ensemble_predictions = np.array(ensemble_predictions.tolist())
        ensemble_actual = top_5_models.iloc[0]['Classified_Actual'].split(',')
        
        ensemble_votes = voting_classification(ensemble_predictions)
        ensemble_accuracy = calculate_accuracy(','.join(ensemble_actual), ','.join(ensemble_votes))

        # Calculate the MSE for the ensemble
        ensemble_actual_values = np.array([float(x) for x in top_5_models.iloc[0]['Normalized_Actual'].split(',')])
        ensemble_predicted_values = np.mean([np.array([float(x) for x in pred.split(',')]) for pred in top_5_models['Normalized_Predicted']], axis=0)
        ensemble_mse = mean_squared_error(ensemble_actual_values, ensemble_predicted_values)

        # Per-category accuracies for top model and ensemble
        categories = ["lower", "moderate", "higher"]
        top_model_category_accuracy = {category: 0 for category in categories}
        ensemble_category_accuracy = {category: 0 for category in categories}

        for category in categories:
            # Top model category accuracy
            top_model_category_count = top_model['Classified_Actual'].split(',').count(category)
            if top_model_category_count > 0:
                top_model_category_accuracy[category] = sum(1 for a, p in zip(top_model['Classified_Actual'].split(','), top_model['Classified_Predicted'].split(',')) if a == p == category) / top_model_category_count
            else:
                top_model_category_accuracy[category] = None
            
            # Ensemble category accuracy
            ensemble_category_count = ensemble_actual.count(category)
            if ensemble_category_count > 0:
                ensemble_category_accuracy[category] = sum(1 for a, p in zip(ensemble_actual, ensemble_votes) if a == p == category) / ensemble_category_count
            else:
                ensemble_category_accuracy[category] = None

        # Correct ensemble features concatenation
        ensemble_features = set()
        for _, row in top_5_models.iterrows():
            try:
                features = ast.literal_eval(row['Selected Features'])
            except (ValueError, SyntaxError):
                features = row['Selected Features'].split(', ')
            ensemble_features.update(features)

        # Print results
        print(f"\n{function} ({norm_type}) Results:")
        print(f"Top Model MSE: {top_model['MSE']:.4f}")
        print(f"Features used in Top Model: {', '.join(sorted(top_features))}")
        for category in categories:
            top_acc = top_model_category_accuracy[category]
            if top_acc is not None:
                print(f"Top Model Accuracy for '{category}': {top_acc:.2%}")
            else:
                print(f"Top Model Accuracy for '{category}': N/A")
        print(f"Classified Actual: {top_model['Classified_Actual']}")
        print(f"Classified Predicted: {top_model['Classified_Predicted']}")

        print()
        print(f"\nEnsemble MSE: {ensemble_mse:.4f}")
        print(f"Ensemble Accuracy: {ensemble_accuracy:.2%}, Ensemble Features: {', '.join(sorted(ensemble_features))}")
        for category in categories:
            ensemble_acc = ensemble_category_accuracy[category]
            if ensemble_acc is not None:
                print(f"Ensemble Accuracy for '{category}': {ensemble_acc:.2%}")
            else:
                print(f"Ensemble Accuracy for '{category}': N/A")
# Out:
# WS (non_norm) Results:
# Top Model MSE: 0.2627
# Features used in Top Model: F22, F24, F31, F43
# Top Model Accuracy for 'lower': 85.71%
# Top Model Accuracy for 'moderate': 71.43%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: lower,higher,higher,higher,higher,lower,moderate,moderate,moderate,moderate,moderate,lower,lower,moderate,moderate,moderate,lower,moderate,moderate,lower,lower,lower,lower,moderate,moderate,lower,moderate,moderate,moderate,moderate,moderate,higher,moderate,lower,lower,higher,moderate,lower,higher,lower,moderate,moderate
# Classified Predicted: moderate,higher,higher,higher,higher,lower,moderate,higher,moderate,higher,lower,lower,lower,moderate,moderate,moderate,lower,moderate,higher,lower,lower,lower,lower,moderate,moderate,lower,moderate,moderate,moderate,moderate,lower,higher,moderate,lower,moderate,higher,moderate,lower,higher,lower,higher,moderate
#
#
# Ensemble MSE: 0.3324
# Ensemble Accuracy: 73.81%, Ensemble Features: F22, F23, F24, F28, F30, F31, F43, F44, F46
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 47.62%
# Ensemble Accuracy for 'higher': 100.00%
#
# WS (norm) Results:
# Top Model MSE: 0.4642
# Features used in Top Model: F22, F31, F43
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 71.43%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: lower,higher,higher,higher,higher,lower,moderate,moderate,moderate,moderate,lower,lower,lower,lower,lower,moderate,lower,lower,moderate,lower,lower,lower,lower,lower,lower,lower,moderate,moderate,moderate,moderate,lower,higher,moderate,lower,lower,higher,moderate,lower,higher,lower,moderate,moderate
# Classified Predicted: lower,higher,higher,higher,higher,lower,moderate,higher,moderate,higher,lower,lower,lower,lower,lower,moderate,lower,lower,higher,lower,lower,lower,lower,lower,lower,lower,moderate,moderate,moderate,moderate,lower,higher,moderate,lower,lower,higher,moderate,lower,higher,lower,higher,moderate
#
#
# Ensemble MSE: 0.5503
# Ensemble Accuracy: 90.48%, Ensemble Features: F22, F24, F28, F30, F31, F43, F44, F46
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 71.43%
# Ensemble Accuracy for 'higher': 100.00%
#
# WS (non_norm_post) Results:
# Top Model MSE: 0.5250
# Features used in Top Model: F22, F24, F31, F43
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 71.43%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: lower,higher,higher,higher,higher,lower,moderate,moderate,moderate,moderate,lower,lower,lower,lower,lower,moderate,lower,lower,moderate,lower,lower,lower,lower,lower,lower,lower,moderate,moderate,moderate,moderate,lower,higher,moderate,lower,lower,higher,moderate,lower,higher,lower,moderate,moderate
# Classified Predicted: lower,higher,higher,higher,higher,lower,moderate,higher,moderate,higher,lower,lower,lower,lower,lower,moderate,lower,lower,higher,lower,lower,lower,lower,lower,lower,lower,moderate,moderate,moderate,moderate,lower,higher,moderate,lower,lower,higher,moderate,lower,higher,lower,higher,moderate
#
#
# Ensemble MSE: 0.6669
# Ensemble Accuracy: 90.48%, Ensemble Features: F22, F23, F24, F28, F30, F31, F43, F44, F46
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 71.43%
# Ensemble Accuracy for 'higher': 100.00%
#
# PR (non_norm) Results:
# Top Model MSE: 0.3721
# Features used in Top Model: F43, F44, F45
# Top Model Accuracy for 'lower': N/A
# Top Model Accuracy for 'moderate': 96.15%
# Top Model Accuracy for 'higher': 75.00%
# Classified Actual: moderate,higher,higher,higher,higher,moderate,moderate,higher,moderate,higher,moderate,moderate,moderate,moderate,moderate,higher,moderate,moderate,higher,moderate,moderate,moderate,moderate,moderate,moderate,moderate,higher,moderate,moderate,moderate,moderate,higher,higher,higher,higher,higher,moderate,moderate,higher,moderate,higher,moderate
# Classified Predicted: moderate,higher,higher,higher,higher,moderate,moderate,higher,moderate,higher,moderate,moderate,moderate,moderate,moderate,higher,moderate,moderate,higher,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,higher,moderate,moderate,moderate,higher,moderate,moderate,higher,moderate,higher,higher
#
#
# Ensemble MSE: 0.3318
# Ensemble Accuracy: 90.48%, Ensemble Features: F1, F43, F44, F45
# Ensemble Accuracy for 'lower': N/A
# Ensemble Accuracy for 'moderate': 96.15%
# Ensemble Accuracy for 'higher': 81.25%
#
# PR (norm) Results:
# Top Model MSE: 0.5237
# Features used in Top Model: F43, F44, F45, Federal_Class
# Top Model Accuracy for 'lower': 0.00%
# Top Model Accuracy for 'moderate': 100.00%
# Top Model Accuracy for 'higher': 78.57%
# Classified Actual: moderate,higher,higher,higher,higher,moderate,moderate,higher,lower,higher,moderate,lower,moderate,lower,moderate,higher,moderate,lower,higher,moderate,moderate,moderate,moderate,moderate,lower,moderate,moderate,moderate,moderate,moderate,lower,higher,higher,higher,moderate,higher,moderate,moderate,higher,lower,higher,moderate
# Classified Predicted: moderate,higher,higher,higher,higher,moderate,moderate,higher,moderate,higher,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,higher,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,higher,moderate,moderate,moderate,higher,moderate,moderate,higher,moderate,higher,moderate
#
#
# Ensemble MSE: 0.4916
# Ensemble Accuracy: 76.19%, Ensemble Features: F1, F43, F44, F45, Federal_Class
# Ensemble Accuracy for 'lower': 0.00%
# Ensemble Accuracy for 'moderate': 100.00%
# Ensemble Accuracy for 'higher': 78.57%
#
# PR (non_norm_post) Results:
# Top Model MSE: 0.5917
# Features used in Top Model: F43, F44, F45
# Top Model Accuracy for 'lower': 0.00%
# Top Model Accuracy for 'moderate': 100.00%
# Top Model Accuracy for 'higher': 85.71%
# Classified Actual: moderate,higher,higher,higher,higher,moderate,moderate,higher,lower,higher,moderate,lower,moderate,lower,moderate,higher,moderate,lower,higher,moderate,moderate,moderate,moderate,moderate,lower,moderate,moderate,moderate,moderate,moderate,lower,higher,higher,higher,moderate,higher,moderate,moderate,higher,lower,higher,moderate
# Classified Predicted: moderate,higher,higher,higher,higher,moderate,moderate,higher,moderate,higher,moderate,moderate,moderate,moderate,moderate,higher,moderate,moderate,higher,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,higher,moderate,moderate,moderate,higher,moderate,moderate,higher,moderate,higher,moderate
#
#
# Ensemble MSE: 0.5276
# Ensemble Accuracy: 76.19%, Ensemble Features: F1, F43, F44, F45
# Ensemble Accuracy for 'lower': 0.00%
# Ensemble Accuracy for 'moderate': 100.00%
# Ensemble Accuracy for 'higher': 78.57%
#
# NR (non_norm) Results:
# Top Model MSE: 0.2786
# Features used in Top Model: F24, F43, F44, F45
# Top Model Accuracy for 'lower': N/A
# Top Model Accuracy for 'moderate': 0.00%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: higher,higher,higher,higher,higher,moderate,higher,higher,higher,higher,higher,moderate,moderate,higher,higher,higher,higher,higher,higher,higher,higher,higher,moderate,higher,higher,higher,higher,higher,higher,higher,higher,higher,moderate,higher,higher,higher,higher,moderate,higher,higher,higher,higher
# Classified Predicted: higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher,higher
#
#
# Ensemble MSE: 0.3431
# Ensemble Accuracy: 85.71%, Ensemble Features: F24, F30, F43, F44, F45, F46, Provincial_Class
# Ensemble Accuracy for 'lower': N/A
# Ensemble Accuracy for 'moderate': 0.00%
# Ensemble Accuracy for 'higher': 100.00%
#
# NR (norm) Results:
# Top Model MSE: 0.7361
# Features used in Top Model: F24, F43, F44, F45
# Top Model Accuracy for 'lower': 73.33%
# Top Model Accuracy for 'moderate': 87.50%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: moderate,higher,higher,higher,higher,lower,moderate,higher,lower,higher,moderate,lower,lower,lower,moderate,moderate,moderate,moderate,higher,lower,lower,moderate,lower,moderate,moderate,lower,lower,lower,moderate,lower,moderate,higher,lower,moderate,moderate,higher,moderate,lower,higher,lower,higher,moderate
# Classified Predicted: moderate,higher,higher,higher,higher,moderate,moderate,higher,lower,higher,moderate,lower,lower,lower,moderate,lower,lower,moderate,higher,lower,moderate,moderate,lower,moderate,moderate,moderate,moderate,lower,moderate,lower,moderate,higher,lower,moderate,moderate,higher,moderate,lower,higher,lower,higher,moderate
#
#
# Ensemble MSE: 0.9285
# Ensemble Accuracy: 71.43%, Ensemble Features: F23, F24, F30, F43, F44, F45, F46, Provincial_Class
# Ensemble Accuracy for 'lower': 73.33%
# Ensemble Accuracy for 'moderate': 50.00%
# Ensemble Accuracy for 'higher': 100.00%
#
# NR (non_norm_post) Results:
# Top Model MSE: 0.5506
# Features used in Top Model: F24, F43, F44, F45
# Top Model Accuracy for 'lower': 80.00%
# Top Model Accuracy for 'moderate': 87.50%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: moderate,higher,higher,higher,higher,lower,moderate,higher,lower,higher,moderate,lower,lower,lower,moderate,moderate,moderate,moderate,higher,lower,lower,moderate,lower,moderate,moderate,lower,lower,lower,moderate,lower,moderate,higher,lower,moderate,moderate,higher,moderate,lower,higher,lower,higher,moderate
# Classified Predicted: moderate,higher,higher,higher,higher,lower,moderate,higher,moderate,higher,moderate,lower,lower,lower,moderate,lower,lower,moderate,higher,lower,moderate,moderate,lower,moderate,moderate,lower,moderate,lower,moderate,lower,moderate,higher,lower,moderate,moderate,higher,moderate,lower,higher,lower,higher,moderate
#
#
# Ensemble MSE: 0.7044
# Ensemble Accuracy: 76.19%, Ensemble Features: F24, F30, F43, F44, F45, F46, Provincial_Class
# Ensemble Accuracy for 'lower': 73.33%
# Ensemble Accuracy for 'moderate': 62.50%
# Ensemble Accuracy for 'higher': 100.00%
#
# SR (non_norm) Results:
# Top Model MSE: 0.6319
# Features used in Top Model: F24, F28, F29, F31, F43
# Top Model Accuracy for 'lower': 0.00%
# Top Model Accuracy for 'moderate': 100.00%
# Top Model Accuracy for 'higher': 72.73%
# Classified Actual: moderate,higher,higher,higher,higher,moderate,moderate,higher,moderate,higher,moderate,lower,lower,moderate,moderate,moderate,moderate,moderate,higher,moderate,moderate,moderate,lower,moderate,moderate,moderate,moderate,lower,moderate,moderate,moderate,higher,lower,moderate,moderate,higher,moderate,moderate,higher,moderate,higher,moderate
# Classified Predicted: moderate,moderate,moderate,higher,higher,moderate,moderate,higher,moderate,higher,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,higher,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,higher,moderate,moderate,moderate,moderate,moderate,moderate,higher,moderate,higher,moderate
#
#
# Ensemble MSE: 0.9037
# Ensemble Accuracy: 88.10%, Ensemble Features: F24, F28, F29, F31, F43, F44, F45, F46
# Ensemble Accuracy for 'lower': 0.00%
# Ensemble Accuracy for 'moderate': 100.00%
# Ensemble Accuracy for 'higher': 100.00%
#
# SR (norm) Results:
# Top Model MSE: 0.8303
# Features used in Top Model: F24, F28, F29, F44
# Top Model Accuracy for 'lower': 82.61%
# Top Model Accuracy for 'moderate': 100.00%
# Top Model Accuracy for 'higher': 80.00%
# Classified Actual: moderate,moderate,higher,higher,higher,lower,moderate,higher,lower,higher,lower,lower,lower,lower,moderate,lower,lower,moderate,higher,lower,lower,moderate,lower,moderate,lower,lower,lower,lower,moderate,lower,lower,higher,lower,lower,lower,higher,moderate,lower,higher,lower,higher,lower
# Classified Predicted: moderate,moderate,moderate,higher,higher,lower,moderate,higher,lower,higher,moderate,lower,lower,lower,moderate,lower,lower,moderate,higher,lower,lower,moderate,lower,moderate,moderate,lower,lower,lower,moderate,lower,moderate,higher,lower,lower,lower,moderate,moderate,lower,higher,lower,higher,moderate
#
#
# Ensemble MSE: 1.0123
# Ensemble Accuracy: 85.71%, Ensemble Features: F24, F28, F29, F31, F43, F44, F45, F46, Provincial_Class
# Ensemble Accuracy for 'lower': 82.61%
# Ensemble Accuracy for 'moderate': 100.00%
# Ensemble Accuracy for 'higher': 80.00%
#
# SR (non_norm_post) Results:
# Top Model MSE: 1.0629
# Features used in Top Model: F24, F28, F29, F31, F43
# Top Model Accuracy for 'lower': 82.61%
# Top Model Accuracy for 'moderate': 100.00%
# Top Model Accuracy for 'higher': 80.00%
# Classified Actual: moderate,moderate,higher,higher,higher,lower,moderate,higher,lower,higher,lower,lower,lower,lower,moderate,lower,lower,moderate,higher,lower,lower,moderate,lower,moderate,lower,lower,lower,lower,moderate,lower,lower,higher,lower,lower,lower,higher,moderate,lower,higher,lower,higher,lower
# Classified Predicted: moderate,moderate,moderate,higher,higher,lower,moderate,higher,lower,higher,moderate,lower,lower,lower,moderate,lower,lower,moderate,higher,lower,lower,moderate,lower,moderate,moderate,lower,lower,lower,moderate,lower,moderate,higher,lower,lower,lower,moderate,moderate,lower,higher,lower,higher,moderate
#
#
# Ensemble MSE: 1.5202
# Ensemble Accuracy: 83.33%, Ensemble Features: F24, F28, F29, F31, F43, F44, F45, F46
# Ensemble Accuracy for 'lower': 82.61%
# Ensemble Accuracy for 'moderate': 66.67%
# Ensemble Accuracy for 'higher': 100.00%
#
# SFST (non_norm) Results:
# Top Model MSE: 0.2953
# Features used in Top Model: F30, F43, F44, F45, F46
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 100.00%
# Top Model Accuracy for 'higher': 0.00%
# Classified Actual: higher,lower,lower,lower,lower,moderate,moderate,lower,moderate,lower,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,lower,moderate,moderate,higher,moderate,higher,higher,moderate,moderate,moderate,moderate,moderate,moderate,lower,moderate,moderate,moderate,lower,moderate,moderate,lower,moderate,lower,moderate
# Classified Predicted: moderate,lower,lower,lower,lower,moderate,moderate,lower,moderate,lower,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,lower,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,lower,moderate,moderate,moderate,lower,moderate,moderate,lower,moderate,lower,moderate
#
#
# Ensemble MSE: 0.3047
# Ensemble Accuracy: 90.48%, Ensemble Features: F30, F31, F43, F44, F45, F46
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 100.00%
# Ensemble Accuracy for 'higher': 0.00%
#
# SFST (norm) Results:
# Top Model MSE: 0.4846
# Features used in Top Model: F30, F43, F44, F45, F46
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 66.67%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: higher,lower,lower,lower,lower,moderate,moderate,lower,moderate,moderate,higher,higher,higher,moderate,higher,moderate,higher,moderate,lower,higher,higher,higher,higher,higher,higher,higher,moderate,moderate,moderate,moderate,higher,moderate,moderate,higher,higher,lower,moderate,higher,lower,higher,lower,moderate
# Classified Predicted: higher,lower,lower,lower,lower,higher,moderate,lower,moderate,lower,higher,higher,higher,higher,higher,moderate,higher,higher,lower,higher,higher,higher,higher,higher,higher,higher,moderate,moderate,moderate,moderate,higher,lower,moderate,higher,higher,lower,moderate,higher,lower,higher,lower,moderate
#
#
# Ensemble MSE: 0.4932
# Ensemble Accuracy: 88.10%, Ensemble Features: F30, F31, F43, F44, F45, F46, Federal_Class
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 66.67%
# Ensemble Accuracy for 'higher': 100.00%
#
# SFST (non_norm_post) Results:
# Top Model MSE: 0.4967
# Features used in Top Model: F30, F43, F44, F45, F46
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 66.67%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: higher,lower,lower,lower,lower,moderate,moderate,lower,moderate,moderate,higher,higher,higher,moderate,higher,moderate,higher,moderate,lower,higher,higher,higher,higher,higher,higher,higher,moderate,moderate,moderate,moderate,higher,moderate,moderate,higher,higher,lower,moderate,higher,lower,higher,lower,moderate
# Classified Predicted: higher,lower,lower,lower,lower,higher,moderate,lower,moderate,lower,higher,higher,higher,higher,higher,moderate,higher,higher,lower,higher,higher,higher,higher,higher,higher,higher,moderate,moderate,moderate,moderate,higher,lower,moderate,higher,higher,lower,moderate,higher,lower,higher,lower,moderate
#
#
# Ensemble MSE: 0.5126
# Ensemble Accuracy: 88.10%, Ensemble Features: F30, F31, F43, F44, F45, F46
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 66.67%
# Ensemble Accuracy for 'higher': 100.00%
#
# WS_Benefit (non_norm) Results:
# Top Model MSE: 0.7507
# Features used in Top Model: F51, F65, OF17, OF23, OF24
# Top Model Accuracy for 'lower': 75.00%
# Top Model Accuracy for 'moderate': 81.82%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: lower,lower,moderate,lower,lower,moderate,moderate,higher,lower,lower,lower,lower,moderate,higher,lower,higher,moderate,lower,moderate,moderate,lower,lower,lower,lower,lower,lower,moderate,lower,lower,lower,lower,lower,lower,moderate,moderate,lower,moderate,lower,lower,lower,lower,lower
# Classified Predicted: lower,lower,lower,lower,lower,moderate,moderate,higher,lower,moderate,lower,lower,moderate,higher,lower,higher,moderate,lower,moderate,moderate,lower,lower,lower,moderate,moderate,lower,moderate,lower,lower,lower,lower,lower,lower,moderate,moderate,moderate,lower,moderate,lower,moderate,moderate,lower
#
#
# Ensemble MSE: 0.7298
# Ensemble Accuracy: 78.57%, Ensemble Features: F49, F51, F52, F54, F65, OF17, OF23, OF24
# Ensemble Accuracy for 'lower': 96.43%
# Ensemble Accuracy for 'moderate': 27.27%
# Ensemble Accuracy for 'higher': 100.00%
#
# WS_Benefit (norm) Results:
# Top Model MSE: 0.8751
# Features used in Top Model: F51, Hydrogeomorphic_Class, OF17, OF23, OF24
# Top Model Accuracy for 'lower': 89.66%
# Top Model Accuracy for 'moderate': 70.00%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: lower,lower,moderate,lower,lower,moderate,moderate,higher,lower,lower,lower,lower,moderate,higher,lower,higher,moderate,lower,moderate,moderate,lower,lower,lower,lower,lower,lower,moderate,lower,lower,lower,lower,lower,lower,moderate,moderate,lower,lower,lower,lower,lower,lower,lower
# Classified Predicted: lower,lower,lower,lower,lower,moderate,moderate,higher,lower,moderate,lower,lower,lower,higher,lower,higher,moderate,lower,moderate,lower,lower,lower,lower,moderate,lower,lower,moderate,lower,lower,lower,lower,lower,lower,moderate,moderate,lower,lower,moderate,lower,lower,lower,lower
#
#
# Ensemble MSE: 0.7858
# Ensemble Accuracy: 80.95%, Ensemble Features: F51, F54, Hydrogeomorphic_Class, OF17, OF23, OF24
# Ensemble Accuracy for 'lower': 96.55%
# Ensemble Accuracy for 'moderate': 30.00%
# Ensemble Accuracy for 'higher': 100.00%
#
# WS_Benefit (non_norm_post) Results:
# Top Model MSE: 1.2627
# Features used in Top Model: F51, F65, OF17, OF23, OF24
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 12.50%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: lower,lower,moderate,lower,lower,moderate,moderate,higher,lower,lower,lower,lower,moderate,higher,lower,higher,moderate,lower,moderate,moderate,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,moderate,lower,lower,lower,lower,lower,lower,lower,lower
# Classified Predicted: lower,lower,lower,lower,lower,lower,lower,higher,lower,lower,lower,lower,lower,higher,lower,higher,moderate,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower
#
#
# Ensemble MSE: 1.2092
# Ensemble Accuracy: 83.33%, Ensemble Features: F49, F51, F52, F54, F65, OF17, OF23, OF24
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 12.50%
# Ensemble Accuracy for 'higher': 100.00%
#
# PR_Benefit (non_norm) Results:
# Top Model MSE: 1.2611
# Features used in Top Model: F14, F41, F43, OF19
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 88.89%
# Top Model Accuracy for 'higher': 30.00%
# Classified Actual: higher,lower,lower,lower,lower,moderate,higher,lower,moderate,lower,moderate,moderate,higher,lower,moderate,lower,lower,moderate,lower,higher,moderate,higher,lower,higher,higher,lower,lower,lower,higher,lower,higher,lower,lower,lower,lower,lower,lower,higher,lower,moderate,lower,moderate
# Classified Predicted: higher,lower,lower,lower,lower,lower,moderate,lower,moderate,lower,moderate,moderate,moderate,lower,moderate,lower,lower,moderate,lower,moderate,moderate,higher,lower,moderate,moderate,lower,lower,lower,moderate,lower,higher,lower,lower,lower,lower,lower,lower,moderate,lower,moderate,lower,moderate
#
#
# Ensemble MSE: 1.4925
# Ensemble Accuracy: 80.95%, Ensemble Features: F1, F14, F31, F41, F43, F44, F46, Hydrogeomorphic_Class, OF19
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 77.78%
# Ensemble Accuracy for 'higher': 40.00%
#
# PR_Benefit (norm) Results:
# Top Model MSE: 1.3627
# Features used in Top Model: F14, F41, F43, OF19
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 90.91%
# Top Model Accuracy for 'higher': 37.50%
# Classified Actual: higher,lower,lower,lower,lower,moderate,higher,lower,moderate,lower,moderate,moderate,higher,lower,moderate,lower,lower,moderate,lower,higher,moderate,higher,lower,moderate,higher,lower,lower,lower,higher,lower,higher,lower,lower,lower,lower,lower,lower,moderate,lower,moderate,lower,moderate
# Classified Predicted: higher,lower,lower,lower,lower,lower,moderate,lower,moderate,lower,moderate,moderate,moderate,lower,moderate,lower,lower,moderate,lower,moderate,moderate,higher,lower,moderate,moderate,lower,lower,lower,moderate,lower,higher,lower,lower,lower,lower,lower,lower,moderate,lower,moderate,lower,moderate
#
#
# Ensemble MSE: 1.7460
# Ensemble Accuracy: 83.33%, Ensemble Features: F14, F41, F43, F44, F46, OF19
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 81.82%
# Ensemble Accuracy for 'higher': 37.50%
#
# PR_Benefit (non_norm_post) Results:
# Top Model MSE: 1.5057
# Features used in Top Model: F14, F41, OF19
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 92.31%
# Top Model Accuracy for 'higher': 50.00%
# Classified Actual: higher,lower,lower,lower,lower,moderate,moderate,lower,moderate,lower,moderate,moderate,higher,lower,moderate,lower,lower,moderate,lower,higher,moderate,higher,lower,moderate,moderate,lower,lower,lower,higher,lower,higher,lower,lower,lower,lower,lower,lower,moderate,lower,moderate,lower,moderate
# Classified Predicted: higher,lower,lower,lower,lower,lower,moderate,lower,moderate,lower,moderate,moderate,moderate,lower,moderate,lower,lower,moderate,lower,moderate,moderate,higher,lower,moderate,moderate,lower,lower,lower,moderate,lower,higher,lower,lower,lower,lower,lower,lower,moderate,lower,moderate,lower,moderate
#
#
# Ensemble MSE: 1.8070
# Ensemble Accuracy: 90.48%, Ensemble Features: F1, F14, F31, F41, F43, F44, F46, Hydrogeomorphic_Class, OF19
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 92.31%
# Ensemble Accuracy for 'higher': 50.00%
#
# NR_Benefit (non_norm) Results:
# Top Model MSE: 3.0280
# Features used in Top Model: F14, F41, OF10, OF19, OF9
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 87.50%
# Top Model Accuracy for 'higher': 75.00%
# Classified Actual: higher,moderate,lower,lower,lower,higher,moderate,lower,moderate,lower,higher,moderate,moderate,moderate,lower,lower,moderate,moderate,lower,higher,moderate,higher,lower,moderate,moderate,moderate,moderate,lower,higher,lower,higher,lower,lower,lower,lower,higher,lower,moderate,lower,moderate,lower,moderate
# Classified Predicted: higher,moderate,lower,lower,lower,lower,moderate,lower,moderate,lower,higher,moderate,lower,moderate,lower,lower,moderate,moderate,lower,higher,moderate,higher,lower,higher,moderate,moderate,moderate,lower,moderate,lower,higher,lower,lower,lower,lower,higher,lower,moderate,lower,moderate,lower,moderate
#
#
# Ensemble MSE: 3.2099
# Ensemble Accuracy: 92.86%, Ensemble Features: F14, F41, F43, Federal_Class, OF10, OF19, OF22, OF9
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 93.75%
# Ensemble Accuracy for 'higher': 75.00%
#
# NR_Benefit (norm) Results:
# Top Model MSE: 3.4702
# Features used in Top Model: F14, OF10, OF19, OF9
# Top Model Accuracy for 'lower': 85.71%
# Top Model Accuracy for 'moderate': 69.23%
# Top Model Accuracy for 'higher': 75.00%
# Classified Actual: higher,moderate,lower,lower,lower,higher,moderate,lower,lower,lower,higher,moderate,moderate,moderate,lower,lower,moderate,moderate,lower,higher,lower,higher,lower,moderate,moderate,moderate,moderate,lower,higher,lower,higher,lower,lower,lower,lower,higher,lower,moderate,lower,moderate,lower,lower
# Classified Predicted: higher,moderate,lower,lower,lower,moderate,moderate,lower,moderate,lower,higher,lower,lower,moderate,lower,lower,moderate,lower,lower,higher,lower,higher,lower,moderate,moderate,moderate,moderate,lower,lower,lower,higher,lower,lower,lower,moderate,higher,moderate,lower,lower,moderate,lower,lower
#
#
# Ensemble MSE: 3.9044
# Ensemble Accuracy: 83.33%, Ensemble Features: F14, F41, F65, OF10, OF19, OF22, OF9, Provincial_Class
# Ensemble Accuracy for 'lower': 95.24%
# Ensemble Accuracy for 'moderate': 69.23%
# Ensemble Accuracy for 'higher': 75.00%
#
# NR_Benefit (non_norm_post) Results:
# Top Model MSE: 5.2476
# Features used in Top Model: F14, OF10, OF19, OF9
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 88.89%
# Top Model Accuracy for 'higher': 75.00%
# Classified Actual: higher,moderate,lower,lower,lower,higher,moderate,lower,lower,lower,higher,lower,moderate,moderate,lower,lower,moderate,lower,lower,higher,lower,higher,lower,moderate,moderate,moderate,moderate,lower,higher,lower,higher,lower,lower,lower,lower,higher,lower,lower,lower,lower,lower,lower
# Classified Predicted: higher,moderate,lower,lower,lower,lower,moderate,lower,lower,lower,higher,lower,lower,moderate,lower,lower,moderate,lower,lower,higher,lower,higher,lower,moderate,moderate,moderate,moderate,lower,lower,lower,higher,lower,lower,lower,lower,higher,lower,lower,lower,lower,lower,lower
#
#
# Ensemble MSE: 5.8856
# Ensemble Accuracy: 92.86%, Ensemble Features: F14, F41, F43, Federal_Class, OF10, OF19, OF22, OF9
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 88.89%
# Ensemble Accuracy for 'higher': 75.00%
#
# SR_Benefit (non_norm) Results:
# Top Model MSE: 0.6983
# Features used in Top Model: F41, OF19, OF20, OF21
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 92.86%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: higher,lower,lower,lower,lower,moderate,moderate,lower,moderate,lower,moderate,moderate,moderate,lower,moderate,lower,lower,moderate,lower,higher,moderate,higher,lower,moderate,moderate,lower,lower,lower,higher,lower,higher,lower,lower,lower,lower,lower,lower,moderate,lower,moderate,lower,moderate
# Classified Predicted: higher,lower,lower,lower,lower,higher,moderate,lower,moderate,lower,moderate,moderate,moderate,lower,moderate,lower,lower,moderate,lower,higher,moderate,higher,lower,moderate,moderate,lower,lower,lower,higher,lower,higher,lower,lower,lower,lower,lower,lower,moderate,lower,moderate,lower,moderate
#
#
# Ensemble MSE: 1.3906
# Ensemble Accuracy: 92.86%, Ensemble Features: F14, F41, Moss_Cover, OF19, OF20, OF21
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 92.86%
# Ensemble Accuracy for 'higher': 60.00%
#
# SR_Benefit (norm) Results:
# Top Model MSE: 2.0620
# Features used in Top Model: F41, OF19, OF21
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 92.86%
# Top Model Accuracy for 'higher': 60.00%
# Classified Actual: higher,lower,lower,lower,lower,moderate,moderate,lower,moderate,lower,moderate,moderate,moderate,lower,moderate,lower,lower,moderate,lower,higher,moderate,higher,lower,moderate,moderate,lower,lower,lower,higher,lower,higher,lower,lower,lower,lower,lower,lower,moderate,lower,moderate,lower,moderate
# Classified Predicted: higher,lower,lower,lower,lower,higher,moderate,lower,moderate,lower,moderate,moderate,moderate,lower,moderate,lower,lower,moderate,lower,moderate,moderate,higher,lower,moderate,moderate,lower,lower,lower,moderate,lower,higher,lower,lower,lower,lower,lower,lower,moderate,lower,moderate,lower,moderate
#
#
# Ensemble MSE: 2.0020
# Ensemble Accuracy: 92.86%, Ensemble Features: F14, F29, F3_c, F41, OF19, OF20, OF21
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 92.86%
# Ensemble Accuracy for 'higher': 60.00%
#
# SR_Benefit (non_norm_post) Results:
# Top Model MSE: 1.0588
# Features used in Top Model: F41, OF19, OF20, OF21
# Top Model Accuracy for 'lower': 100.00%
# Top Model Accuracy for 'moderate': 0.00%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: higher,lower,lower,lower,lower,moderate,lower,lower,lower,lower,lower,lower,moderate,lower,lower,lower,lower,lower,lower,higher,lower,higher,lower,lower,lower,lower,lower,lower,higher,lower,higher,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower
# Classified Predicted: higher,lower,lower,lower,lower,higher,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,higher,lower,higher,lower,lower,lower,lower,lower,lower,higher,lower,higher,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower,lower
#
#
# Ensemble MSE: 2.2024
# Ensemble Accuracy: 90.48%, Ensemble Features: F14, F41, Moss_Cover, OF19, OF20, OF21
# Ensemble Accuracy for 'lower': 100.00%
# Ensemble Accuracy for 'moderate': 0.00%
# Ensemble Accuracy for 'higher': 60.00%
#
# SFST_Benefit (non_norm) Results:
# Top Model MSE: 1.1648
# Features used in Top Model: F1, F43, F44, F46
# Top Model Accuracy for 'lower': 73.33%
# Top Model Accuracy for 'moderate': 100.00%
# Top Model Accuracy for 'higher': 0.00%
# Classified Actual: moderate,lower,lower,lower,lower,moderate,moderate,lower,moderate,lower,moderate,moderate,moderate,higher,lower,moderate,moderate,moderate,lower,higher,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,lower,lower,lower,lower,moderate,moderate,moderate,lower,moderate,higher,lower,moderate,lower,moderate
# Classified Predicted: moderate,lower,lower,lower,lower,moderate,moderate,lower,moderate,lower,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,lower,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,moderate,lower,moderate,moderate,moderate,lower,moderate,moderate,lower,moderate,lower,moderate
#
#
# Ensemble MSE: 1.1834
# Ensemble Accuracy: 83.33%, Ensemble Features: F1, F23, F43, F44, F45, F46
# Ensemble Accuracy for 'lower': 73.33%
# Ensemble Accuracy for 'moderate': 100.00%
# Ensemble Accuracy for 'higher': 0.00%
#
# SFST_Benefit (norm) Results:
# Top Model MSE: 2.3641
# Features used in Top Model: F43, F44
# Top Model Accuracy for 'lower': 84.62%
# Top Model Accuracy for 'moderate': 60.00%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: moderate,lower,lower,lower,lower,higher,moderate,lower,moderate,lower,moderate,higher,higher,higher,lower,moderate,higher,moderate,lower,higher,higher,higher,moderate,higher,higher,higher,moderate,moderate,moderate,lower,moderate,lower,moderate,moderate,higher,lower,moderate,higher,lower,higher,lower,moderate
# Classified Predicted: higher,lower,lower,lower,lower,higher,moderate,lower,moderate,lower,higher,higher,higher,higher,higher,moderate,higher,higher,lower,higher,higher,higher,higher,higher,higher,higher,moderate,moderate,moderate,moderate,higher,lower,moderate,higher,higher,lower,moderate,higher,lower,higher,lower,moderate
#
#
# Ensemble MSE: 2.3203
# Ensemble Accuracy: 80.95%, Ensemble Features: F1, F23, F43, F44, F45, F46
# Ensemble Accuracy for 'lower': 84.62%
# Ensemble Accuracy for 'moderate': 60.00%
# Ensemble Accuracy for 'higher': 100.00%
#
# SFST_Benefit (non_norm_post) Results:
# Top Model MSE: 1.9596
# Features used in Top Model: F1, F43, F44, F46
# Top Model Accuracy for 'lower': 84.62%
# Top Model Accuracy for 'moderate': 66.67%
# Top Model Accuracy for 'higher': 100.00%
# Classified Actual: moderate,lower,lower,lower,lower,higher,moderate,lower,moderate,lower,moderate,higher,higher,higher,lower,moderate,higher,moderate,lower,higher,higher,higher,moderate,higher,higher,higher,moderate,moderate,moderate,lower,moderate,lower,moderate,moderate,higher,lower,moderate,higher,lower,higher,lower,moderate
# Classified Predicted: higher,lower,lower,lower,lower,higher,moderate,lower,moderate,lower,higher,higher,higher,higher,higher,moderate,higher,higher,lower,higher,higher,higher,moderate,higher,higher,higher,moderate,moderate,moderate,moderate,higher,lower,moderate,higher,higher,lower,moderate,higher,lower,higher,lower,moderate
#
#
# Ensemble MSE: 1.9908
# Ensemble Accuracy: 83.33%, Ensemble Features: F1, F23, F43, F44, F45, F46
# Ensemble Accuracy for 'lower': 84.62%
# Ensemble Accuracy for 'moderate': 66.67%
# Ensemble Accuracy for 'higher': 100.00%
